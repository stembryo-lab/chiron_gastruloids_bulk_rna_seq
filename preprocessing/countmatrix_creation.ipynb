# %% [markdown]
# # **COUNT MATRIX CREATION**
# ## Alignment files are concatenated into a matrix

# %%
import os
import numpy as np
from numpy import isneginf
import pandas as pd
import glob
import sys
import csv
import re

# %% [markdown]
# ## Load metadata

# %%
meta=pd.read_csv('data/metadata_chir_new.csv')
meta.head()
# Out:
#                  Filename    Sample Condition  Replicate
# 0   A1_S2_R1_001.fastq.gz      0h_1        0h          1
# 1   A2_S8_R1_001.fastq.gz      0h_2        0h          2
# 2   A3_S9_R1_001.fastq.gz      0h_3        0h          3
# 3  A5_S29_R1_001.fastq.gz  0h-Epi_1    0h-Epi          1
# 4  A6_S30_R1_001.fastq.gz  0h-Epi_2    0h-Epi          2

# %% [markdown]
# ## List gene counts files

# %%
path = 'star_out'

files = glob.glob(os.path.join(path , "*_S*/*_ReadsPerGene.out.tab"))

# %%
# retain only files specified in metadata
files=[f for f in files if f.split('/')[1] in meta['Filename'].str.split('_R1').str[0].values]

# %% [markdown]
# ## Sort files according to metadata

# %%
# set order using metadata
order=[x.split('_R1')[0] for x in meta['Filename']]
# sort files
sorted_files=sorted(files, key=lambda x: order.index(x.split('/')[1]))

# %% [markdown]
# ## Countmatrix: read and concatenate

# %%
dfs = []
samples =[]

for filename in sorted_files:
    df = pd.read_csv(filename, index_col=0, header=0, sep='\t', skiprows=3)
    df = df.iloc[:,0] # first column belongs to Unstranded reads (sequencing specififcation)

    dfs.append(df)
    
# concat dfs
counts = pd.concat(dfs, axis=1, ignore_index=True)
# remove genes with 0 counts accross all genes
counts = counts.loc[~(counts==0).all(axis=1)]
# rename columns and index
counts.columns = meta['Sample']
counts.index.name = 'Gene'
counts = counts.fillna(0)


# save df
counts.to_csv(path + '/counts_chir_af_project.csv')
counts
# Out:
# Sample          0h_1  0h_2  0h_3  0h-Epi_1  0h-Epi_2  0h-Epi_3  48h_1  48h_2  \
# Gene
# Xkr4               0     3     0        38        55        41      9      6
# Gm18956            0     0     0         0         0         0      0      0
# Gm37180            0     0     0         4         3         1      2      0
# Gm37363            0     4     0        11        22         1      0      1
# Gm37686            0     0     7         0         9         0      2      1
# ...              ...   ...   ...       ...       ...       ...    ...    ...
# CAAA01147332.1     0     0     0         0         1         0      0      0
# AC163611.1         0     0     0         0         0         0      0      0
# AC140365.1         1     2     0         0         0         0      0      1
# AC133095.2         3     5     4         0         0         0      4      1
# AC149090.1      2215  2007  2027       446       815       629   1418   1519
#
# Sample          48h_3  48h-AF_1  ...  120h-high-ActA_1  120h-high-ActA_2  \
# Gene                             ...
# Xkr4               17        16  ...                27                43
# Gm18956             0         0  ...                 0                 0
# Gm37180             2         7  ...                 9                 5
# Gm37363             8         9  ...                11                11
# Gm37686             3         0  ...                 0                 0
# ...               ...       ...  ...               ...               ...
# CAAA01147332.1      3         0  ...                 2                 4
# AC163611.1          0         0  ...                 0                 0
# AC140365.1          0         0  ...                 0                 0
# AC133095.2          0         2  ...                 0                 0
# AC149090.1       2010      1864  ...              1243              1029
#
# Sample          120h-high-ActA_3  144h-low-ActA_1  144h-low-ActA_2  \
# Gene
# Xkr4                          19                5                0
# Gm18956                        2                0                0
# Gm37180                        0                0                2
# Gm37363                       11                0                5
# Gm37686                        3                0                0
# ...                          ...              ...              ...
# CAAA01147332.1                 2                0                1
# AC163611.1                     0                0                0
# AC140365.1                     0                0                0
# AC133095.2                     0                0                0
# AC149090.1                  1740             2159             1824
#
# Sample          144h-low-ActA_3  144h-high-ActA_1  144h-high-ActA_2  \
# Gene
# Xkr4                          9                21                 7
# Gm18956                       0                 0                 3
# Gm37180                       0                 1                 0
# Gm37363                       4                 0                 0
# Gm37686                       0                 0                 3
# ...                         ...               ...               ...
# CAAA01147332.1                1                 2                 2
# AC163611.1                    0                 0                 0
# AC140365.1                    0                 1                 0
# AC133095.2                    0                 0                 0
# AC149090.1                 2241              3149              2559
#
# Sample          144h-high-ActA_3  96h-3μMc-DMSO_1
# Gene
# Xkr4                          16               46
# Gm18956                        0                0
# Gm37180                        0                6
# Gm37363                        5               11
# Gm37686                        5                5
# ...                          ...              ...
# CAAA01147332.1                 1                0
# AC163611.1                     0                0
# AC140365.1                     0                0
# AC133095.2                     0                1
# AC149090.1                  2086             1564
#
# [39334 rows x 68 columns]
